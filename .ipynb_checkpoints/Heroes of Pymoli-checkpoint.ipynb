# %%
#import pandas Library
import pandas as pd
import numpy as np

# %%
# set path for the json file
HOP_file="/Users/admin/Desktop/HW4/purchase_data.json"

# %%
###### 1. Total numbers of Players, SN is the players' name, and to use extract(unique) SN names
numbers_players=len(HOP_purchase_data['SN'].unique())

#show Data Frame for numers_players
pd.DataFrame({"Total Players":[numbers_players]})
# Out:
#    Total Players
# 0            573

# %%
###### 2. Purchasing Analysis
Number_of_item=len(HOP_purchase_data["Item ID"].unique())
average_price=HOP_purchase_data["Price"].mean()
purchase_count=HOP_purchase_data["Price"].count()
total_revenue_value=HOP_purchase_data["Price"].sum()
#Creat DataFrame for the Sumarrary table
summary_table=pd.DataFrame({"Number of Unique Items":Number_of_item,"Average Price":[average_price],"Number of Purchases":[purchase_count],"Total Revenue":[total_revenue_value]})
df=pd.DataFrame({"Number of Unique Items":Number_of_item,"Average Price":[average_price],"Number of Purchases":[purchase_count],"Total Revenue":[total_revenue_value]})
summary_table_df=df.loc[:,["Number of Unique Items","Average Price","Number of Purchases","Total Revenue"]]
summary_table_df=summary_table_df.round(2)
summary_table_df["Average Price"]=summary_table_df["Average Price"].map("${:,.2f}".format)
summary_table_df["Total Revenue"]=summary_table_df["Total Revenue"].map("${:,.2f}".format)
summary_table_df
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     183         $2.93                  780     $2,286.33

# %%
##### 3. Gender Demographics
Gender_totals= HOP_purchase_data["Gender"].value_counts()
Gender_percents=Gender_totals/numbers_players *100
#Data Frame for Gender
Gender_demographics_df=pd.DataFrame({"Total Count":Gender_totals,"Percentage of Players":Gender_percents})
Gender_demographics_df=Gender_demographics_df.round(2)

Gender_demographics_df
# Out:
#                        Percentage of Players  Total Count
# Male                                  110.47          633
# Female                                 23.73          136
# Other / Non-Disclosed                   1.92           11

# %%
#Observation: There are much more Male Users than Females in the category

# %%
###### 4.Purchasing Analysis by Gender
Gender_Total_Purchase=HOP_purchase_data.groupby(["Gender"]).sum()["Price"].rename("Total Purchase Value")
Gender_ave=HOP_purchase_data.groupby(["Gender"]).mean()["Price"].rename("Average Purchase Price")
Gender_purchase_count=HOP_purchase_data.groupby(["Gender"]).count()["Price"].rename("Purchase Count")
#Normalized 
Normalized_total=Gender_Total_Purchase/Gender_demographics_df["Total Count"]
#Data Frame for Purchasing Analysis by Gender
Gender_table=pd.DataFrame({"Purchase Count":Gender_purchase_count,"Average Purchase Price":Gender_ave,"Total Purchase Value":Gender_Total_Purchase,"Normalized Total":Normalized_total})
df=pd.DataFrame({"Purchase Count":Gender_purchase_count,"Average Purchase Price":Gender_ave,"Total Purchase Value":Gender_Total_Purchase,"Normalized Total":Normalized_total})
Gender_table_df=df.loc[:,["Purchase Count","Average Purchase Price","Total Purchase Value","Normalized Total"]]
Gender_table_df.round(2)
Gender_table_df["Average Purchase Price"]=Gender_table_df["Average Purchase Price"].map("${:,.2f}".format)
Gender_table_df["Total Purchase Value"]=Gender_table_df["Total Purchase Value"].map("${:,.2f}".format)
Gender_table_df["Normalized Total"]=Gender_table_df["Normalized Total"].map("${:,.2f}".format)
Gender_table_df
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            136                  $2.82
# Male                              633                  $2.95
# Other / Non-Disclosed              11                  $3.25
#
#                       Total Purchase Value Normalized Total
# Gender
# Female                             $382.91            $2.82
# Male                             $1,867.68            $2.95
# Other / Non-Disclosed               $35.74            $3.25

# %%
###### 5. Age Demographics
#Create Age bins and groupby
age_bins = [0, 9.90, 14.90, 19.90, 24.9, 29.9, 34.90, 39.90, 9999999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", ">40"]
# Create the category of Players use / use pd.cut with apply
#pd.cut(HOP_purchase_data["Age"],age_bins,labels=group_names)
HOP_purchase_data["Age Range"]=pd.cut(HOP_purchase_data["Age"],age_bins,labels=group_names)
age_demographics_totals=HOP_purchase_data["Age Range"].value_counts()
age_demographics_totals
age_demographics_percent=age_demographics_totals/numbers_players *100
#Data Frame for Age demographcis summary
age_summary=pd.DataFrame({"Percent of Players":age_demographics_percent,"Total Count":age_demographics_totals})
df=pd.DataFrame({"Percent of Players":age_demographics_percent,"Total Count":age_demographics_totals})
age_summary_df=df.loc[:,["Percent of Players","Total Count"]]

age_summary_df=age_summary_df.sort_index()
age_summary_df.round(2)
# Out:
#        Percent of Players  Total Count
# <10                  4.89           28
# 10-14                6.11           35
# 15-19               23.21          133
# 20-24               58.64          336
# 25-29               21.82          125
# 30-34               11.17           64
# 35-39                7.33           42
# >40                  2.97           17

# %%
#Observation: the Age Group 20-24 perform the best in the data

# %%
###### 6.Purchasing Analysis by Age
Age_Total_Purchase=HOP_purchase_data.groupby(["Age Range"]).sum()["Price"].rename("Total Purchase Value")
Age_ave=HOP_purchase_data.groupby(["Age Range"]).mean()["Price"].rename("Average Purchase Price")
Age_purchase_count=HOP_purchase_data.groupby(["Age Range"]).count()["Price"].rename("Purchase Count")
#Normalized 
Age_Normalized_total=Age_Total_Purchase/age_summary_df["Total Count"]
#Data Frame for Purchasing Analysis by Age
Age_table=pd.DataFrame({"Purchase Count":Age_purchase_count,"Average Purchase Price":Age_ave,"Total Purchase Value":Age_Total_Purchase,"Normalized Total":Age_Normalized_total})
df=pd.DataFrame({"Purchase Count":Age_purchase_count,"Average Purchase Price":Age_ave,"Total Purchase Value":Age_Total_Purchase,"Normalized Total":Age_Normalized_total})
Age_table_df=df.loc[:,["Purchase Count","Average Purchase Price","Total Purchase Value","Normalized Total"]]
Age_table_df.round(2)
Age_table_df["Average Purchase Price"]=Age_table_df["Average Purchase Price"].map("${:,.2f}".format)
Age_table_df["Total Purchase Value"]=Age_table_df["Total Purchase Value"].map("${:,.2f}".format)
Age_table_df["Normalized Total"]=Age_table_df["Normalized Total"].map("${:,.2f}".format)
Age_table_df
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Range
# <10                    28                  $2.98               $83.46
# 10-14                  35                  $2.77               $96.95
# 15-19                 133                  $2.91              $386.42
# 20-24                 336                  $2.91              $978.77
# 25-29                 125                  $2.96              $370.33
# 30-34                  64                  $3.08              $197.25
# 35-39                  42                  $2.84              $119.40
# >40                    17                  $3.16               $53.75
#
#           Normalized Total
# Age Range
# <10                  $2.98
# 10-14                $2.77
# 15-19                $2.91
# 20-24                $2.91
# 25-29                $2.96
# 30-34                $3.08
# 35-39                $2.84
# >40                  $3.16

# %%
####### 7. Top Spendings
Players_purchase_count=HOP_purchase_data.groupby(["SN"]).count()["Price"].rename("Purchase Count")
Players_ave= HOP_purchase_data.groupby(["SN"]).mean()["Price"].rename("Average Purchase Price")
Players_Total= HOP_purchase_data.groupby(["SN"]).sum()["Price"].rename("Total Purchase Value")
#Data Frame total user
players_data=pd.DataFrame({"Purchase Count":Players_purchase_count,"Average Purchase Price":Players_ave,"Total Purchase Value":Players_Total})
# Top 5 spenders
df=pd.DataFrame({"Purchase Count":Players_purchase_count,"Average Purchase Price":Players_ave,"Total Purchase Value":Players_Total})
players_data_df=df.loc[:,["Purchase Count","Average Purchase Price","Total Purchase Value"]]
players_data_df["Average Purchase Price"]=players_data_df["Average Purchase Price"].map("${:,.2f}".format)
players_data_df["Total Purchase Value"]=players_data_df["Total Purchase Value"].map("${:,.2f}".format)

players_data_df.sort_values("Total Purchase Value",ascending=False).head(5).round(2)
# Out:
#               Purchase Count Average Purchase Price Total Purchase Value
# SN
# Qarwen67                   4                  $2.49                $9.97
# Sondim43                   3                  $3.13                $9.38
# Tillyrin30                 3                  $3.06                $9.19
# Lisistaya47                3                  $3.06                $9.19
# Tyisriphos58               2                  $4.59                $9.18

# %%
#### 8. Most Popular Items
Players_purchase_count_p=HOP_purchase_data.groupby(["Item ID","Item Name"]).count()["Price"].rename("Purchase Count")
Players_ave_p= HOP_purchase_data.groupby(["Item ID","Item Name"]).mean()["Price"].rename("Items Price")
Players_Total_p= HOP_purchase_data.groupby(["Item ID","Item Name"]).sum()["Price"].rename("Total Purchase Value")
Players_data_popular=pd.DataFrame({"Purchase Count":Players_purchase_count_p,"Items Price":Players_ave_p,"Total Purchase Value":Players_Total_p})
df=pd.DataFrame({"Purchase Count":Players_purchase_count_p,"Items Price":Players_ave_p,"Total Purchase Value":Players_Total_p})
Players_data_popular_df=df.loc[:,["Purchase Count","Items Price","Total Purchase Value"]]
Players_data_popular_df["Items Price"]=Players_data_popular_df["Items Price"].map("${:,.2f}".format)
Players_data_popular_df["Total Purchase Value"]=Players_data_popular_df["Total Purchase Value"].map("${:,.2f}".format)
Players_data_popular_df.sort_values("Purchase Count",ascending=False).head(5)
# Out:
#                                               Purchase Count Items Price  \
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows              11       $2.35
# 84      Arcane Gem                                        11       $2.23
# 31      Trickster                                          9       $2.07
# 175     Woeful Adamantite Claymore                         9       $1.24
# 13      Serenity                                           9       $1.49
#
#                                              Total Purchase Value
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows               $25.85
# 84      Arcane Gem                                         $24.53
# 31      Trickster                                          $18.63
# 175     Woeful Adamantite Claymore                         $11.16
# 13      Serenity                                           $13.41

# %%
#Observation: Betrayal, Whisper of Grieving Widows is the most popular item.

# %%
#### 9. Most Profitable Items by sorting the total purchase value
Players_purchase_count_p=HOP_purchase_data.groupby(["Item ID","Item Name"]).count()["Price"].rename("Purchase Count")
Players_ave_p= HOP_purchase_data.groupby(["Item ID","Item Name"]).mean()["Price"].rename("Items Price")
Players_Total_p= HOP_purchase_data.groupby(["Item ID","Item Name"]).sum()["Price"].rename("Total Purchase Value")
Players_data_popular=pd.DataFrame({"Purchase Count":Players_purchase_count_p,"Items Price":Players_ave_p,"Total Purchase Value":Players_Total_p})
df=pd.DataFrame({"Purchase Count":Players_purchase_count_p,"Items Price":Players_ave_p,"Total Purchase Value":Players_Total_p})
Players_data_popular_df=df.loc[:,["Purchase Count","Items Price","Total Purchase Value"]]
Players_data_popular_df["Items Price"]=Players_data_popular_df["Items Price"].map("${:,.2f}".format)
Players_data_popular_df.sort_values("Total Purchase Value",ascending=False).head(5)
# Out:
#                                     Purchase Count Items Price  \
# Item ID Item Name
# 34      Retribution Axe                          9       $4.14
# 115     Spectral Diamond Doomblade               7       $4.25
# 32      Orenmir                                  6       $4.95
# 103     Singed Scalpel                           6       $4.87
# 107     Splitter, Foe Of Subtlety                8       $3.61
#
#                                     Total Purchase Value
# Item ID Item Name
# 34      Retribution Axe                            37.26
# 115     Spectral Diamond Doomblade                 29.75
# 32      Orenmir                                    29.70
# 103     Singed Scalpel                             29.22
# 107     Splitter, Foe Of Subtlety                  28.88

# %%
#Observation: Retribution Axe is the most profitable item in the game
